# %%
import pandas as pd

# %%
df = pd.read_csv("data/cBioportal/genie_public_clinical_data.tsv", sep="\t")

# %%
df.head()
# Out:
#        Study ID           Patient ID                       Sample ID  \
# 0  genie_public  GENIE-CHOP-C1003065  GENIE-CHOP-C1003065-BS66P79BWX
# 1  genie_public  GENIE-CHOP-C1003188  GENIE-CHOP-C1003188-BSHKNH1HNP
# 2  genie_public  GENIE-CHOP-C1003434  GENIE-CHOP-C1003434-BSA2BH219E
# 3  genie_public  GENIE-CHOP-C1003557  GENIE-CHOP-C1003557-BSJ8YRVFDM
# 4  genie_public  GENIE-CHOP-C1003680  GENIE-CHOP-C1003680-BSR1X6B55S
#
#   Age at Which Sequencing was Reported      Cancer Type  \
# 0                                  <18  Embryonal Tumor
# 1                                  <18  Embryonal Tumor
# 2                                  <18           Glioma
# 3                                  <18           Glioma
# 4                                  <18           Glioma
#
#     Cancer Type Detailed Center Vital Status        Ethnicity Category  \
# 0        Medulloblastoma   CHOP        False  Non-Spanish/non-Hispanic
# ...

# %%
df["Study ID"].value_counts()
# Out:
# genie_public    153834
# Name: Study ID, dtype: int64

# %%
df["Cancer Type"].value_counts().head(30)
# Out:
# Non-Small Cell Lung Cancer           22102
# Breast Cancer                        15233
# Colorectal Cancer                    14328
# Glioma                                9161
# Pancreatic Cancer                     6326
# Melanoma                              6315
# Ovarian Cancer                        5648
# Leukemia                              5334
# Prostate Cancer                       5273
# Cancer of Unknown Primary             4806
# Mature B-Cell Neoplasms               4737
# Endometrial Cancer                    4685
# Soft Tissue Sarcoma                   4471
# Bladder Cancer                        4352
# Esophagogastric Cancer                4349
# Hepatobiliary Cancer                  3167
# Renal Cell Carcinoma                  2411
# Thyroid Cancer                        2121
# Blood Cancer, NOS                     2105
# Myeloproliferative Neoplasms          2086
# Head and Neck Cancer                  2076
# Myelodysplastic Syndromes             1952
# ...

# %%
df["Cancer Type Detailed"].value_counts().head(30)
# Out:
# Lung Adenocarcinoma                                        16913
# Breast Invasive Ductal Carcinoma                            9069
# Colon Adenocarcinoma                                        8253
# Pancreatic Adenocarcinoma                                   5423
# Prostate Adenocarcinoma                                     5134
# High-Grade Serous Ovarian Cancer                            3304
# Bladder Urothelial Carcinoma                                3237
# Colorectal Adenocarcinoma                                   3227
# Melanoma                                                    3089
# Acute Myeloid Leukemia                                      2840
# Invasive Breast Carcinoma                                   2713
# Glioblastoma Multiforme                                     2459
# Rectal Adenocarcinoma                                       2377
# Uterine Endometrioid Carcinoma                              2285
# ...

# %%
len(df[df["Cancer Type Detailed"]=="Neurofibroma"])
# Out:
# 69

# %%
df[df["Cancer Type Detailed"]=="Neurofibroma"].head()
# Out:
#           Study ID           Patient ID                       Sample ID  \
# 202   genie_public  GENIE-CHOP-C2396040  GENIE-CHOP-C2396040-BSHNPBMWAD
# 248   genie_public  GENIE-CHOP-C2472915  GENIE-CHOP-C2472915-BS4K3XM3EV
# 479   genie_public  GENIE-CHOP-C3040683  GENIE-CHOP-C3040683-BS4W8TBP0J
# 594   genie_public    GENIE-CHOP-C57687    GENIE-CHOP-C57687-BSKAKP1MAK
# 7633  genie_public    GENIE-DFCI-001970          GENIE-DFCI-001970-9343
#
#      Age at Which Sequencing was Reported         Cancer Type  \
# 202                                   <18  Nerve Sheath Tumor
# 248                                   <18  Nerve Sheath Tumor
# 479                                   <18  Nerve Sheath Tumor
# 594                                    27  Nerve Sheath Tumor
# 7633                                   46  Nerve Sheath Tumor
#
#      Cancer Type Detailed Center Vital Status        Ethnicity Category  \
# 202          Neurofibroma   CHOP        False  Non-Spanish/non-Hispanic
# ...

# %%
df[df["Cancer Type Detailed"]=="Neurofibroma"]["Cancer Type"].value_counts()
# Out:
# Nerve Sheath Tumor    69
# Name: Cancer Type, dtype: int64

# %%
df[df["Cancer Type"]=="Nerve Sheath Tumor"]["Cancer Type Detailed"].value_counts()
# Out:
# Malignant Peripheral Nerve Sheath Tumor    161
# Schwannoma                                 108
# Neurofibroma                                69
# Nerve Sheath Tumor                           9
# Melanotic Schwannoma                         8
# Cellular Schwannoma                          8
# Name: Cancer Type Detailed, dtype: int64
