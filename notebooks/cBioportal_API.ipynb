# %%
# https://docs.cbioportal.org/web-api-and-clients/#r-client

# %%
from bravado.client import SwaggerClient
cbioportal = SwaggerClient.from_url('https://www.cbioportal.org/api/v2/api-docs',
                                    config={"validate_requests":False,"validate_responses":False,"validate_swagger_spec": False})

# %%
dir(cbioportal)
# Out:
# ['Cancer_Types',
#  'Clinical_Attributes',
#  'Clinical_Data',
#  'Copy_Number_Segments',
#  'Discrete_Copy_Number_Alterations',
#  'Gene_Panel_Data',
#  'Gene_Panels',
#  'Generic_Assay_Data',
#  'Generic_Assays',
#  'Genes',
#  'Info',
#  'Molecular_Data',
#  'Molecular_Profiles',
#  'Mutations',
#  'Patients',
#  'Sample_Lists',
#  'Samples',
#  'Server_running_status',
#  'Studies',
#  'Treatments']

# %%
for a in dir(cbioportal):
    cbioportal.__setattr__(a.replace(' ', '_').lower(), cbioportal.__getattr__(a))

# %%
muts = cbioportal.mutations.getMutationsInMolecularProfileBySampleListIdUsingGET(
    molecularProfileId="msk_impact_2017_mutations", # {study_id}_mutations gives default mutations profile for study 
    sampleListId="msk_impact_2017_all", # {study_id}_all includes all samples
    projection="DETAILED" # include gene info
).result()

# %%
muts
# Out:
# [Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='14', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=105246551, entrezGeneId=207, fisValue=1.4013e-45, functionalImpactScore='NA', gene=Gene(entrezGeneId=207, geneticEntityId=None, hugoGeneSymbol='AKT1', type='protein-coding'), keyword='AKT1 E17 missense', linkMsa='NA', linkPdb='NA', linkXvar='NA', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='E17K', proteinPosEnd=17, proteinPosStart=17, referenceAllele='C', refseqMrnaId='NM_001014432.1', sampleId='P-0000004-T01-IM3', startPosition=105246551, studyId='msk_impact_2017', tumorAltCount=244, tumorRefCount=202, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=56440643, entrezGeneId=54894, fisValue=0.55, functionalImpactScore='N', gene=Gene(entrezGeneId=54894, geneticEntityId=None, hugoGeneSymbol='RNF43', type='protein-coding'), keyword='RNF43 P192 missense', linkMsa='http://mutationassessor.org/r3/?cm=msa&ty=f&p=RNF43_HUMAN&rb=1&re=200&var=P192L', linkPdb='http://mutationassessor.org/r3/pdb.php?prot=RNF43_HUMAN&from=1&to=200&var=P192L', linkXvar='P192L', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='P192L', proteinPosEnd=192, proteinPosStart=192, referenceAllele='G', refseqMrnaId='NA', sampleId='P-0000004-T01-IM3', startPosition=56440643, studyId='msk_impact_2017', tumorAltCount=41, tumorRefCount=296, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='5', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=56177843, entrezGeneId=4214, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=4214, geneticEntityId=None, hugoGeneSymbol='MAP3K1', type='protein-coding'), keyword='MAP3K1 S939 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='S939C', proteinPosEnd=939, proteinPosStart=939, referenceAllele='C', refseqMrnaId='NM_005921.1', sampleId='P-0000004-T01-IM3', startPosition=56177843, studyId='msk_impact_2017', tumorAltCount=12, tumorRefCount=370, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='19', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=15303190, entrezGeneId=4854, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=4854, geneticEntityId=None, hugoGeneSymbol='NOTCH3', type='protein-coding'), keyword='NOTCH3 R113 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='R113Q', proteinPosEnd=113, proteinPosStart=113, referenceAllele='C', refseqMrnaId='NM_000435.2', sampleId='P-0000004-T01-IM3', startPosition=15303190, studyId='msk_impact_2017', tumorAltCount=17, tumorRefCount=274, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=7578518, entrezGeneId=7157, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=7157, geneticEntityId=None, hugoGeneSymbol='TP53', type='protein-coding'), keyword='TP53 truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Del', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='A138Cfs*27', proteinPosEnd=138, proteinPosStart=138, referenceAllele='CAGGGCAGGTCTTGGC', refseqMrnaId='NM_001126112.2', sampleId='P-0000004-T01-IM3', startPosition=7578503, studyId='msk_impact_2017', tumorAltCount=58, tumorRefCount=209, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='5', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=180051003, entrezGeneId=2324, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=2324, geneticEntityId=None, hugoGeneSymbol='FLT4', type='protein-coding'), keyword='FLT4 T494 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='T494A', proteinPosEnd=494, proteinPosStart=494, referenceAllele='T', refseqMrnaId='NM_182925.4', sampleId='P-0000004-T01-IM3', startPosition=180051003, studyId='msk_impact_2017', tumorAltCount=22, tumorRefCount=273, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='6', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=32178570, entrezGeneId=4855, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=4855, geneticEntityId=None, hugoGeneSymbol='NOTCH4', type='protein-coding'), keyword='NOTCH4 G942 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='G942R', proteinPosEnd=942, proteinPosStart=942, referenceAllele='C', refseqMrnaId='NM_004557.3', sampleId='P-0000004-T01-IM3', startPosition=32178570, studyId='msk_impact_2017', tumorAltCount=17, tumorRefCount=279, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='1', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=16265908, entrezGeneId=23013, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=23013, geneticEntityId=None, hugoGeneSymbol='SPEN', type='protein-coding'), keyword='SPEN I3661 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='I3661F', proteinPosEnd=3661, proteinPosStart=3661, referenceAllele='A', refseqMrnaId='NM_015001.2', sampleId='P-0000004-T01-IM3', startPosition=16265908, studyId='msk_impact_2017', tumorAltCount=73, tumorRefCount=400, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='7', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=151945083, entrezGeneId=58508, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=58508, geneticEntityId=None, hugoGeneSymbol='KMT2C', type='protein-coding'), keyword='KMT2C M812 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='M812I', proteinPosEnd=812, proteinPosStart=812, referenceAllele='C', refseqMrnaId='NM_170606.2', sampleId='P-0000004-T01-IM3', startPosition=151945083, studyId='msk_impact_2017', tumorAltCount=11, tumorRefCount=84, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='2', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=29543736, entrezGeneId=238, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=238, geneticEntityId=None, hugoGeneSymbol='ALK', type='protein-coding'), keyword='ALK V476 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='V476A', proteinPosEnd=476, proteinPosStart=476, referenceAllele='A', refseqMrnaId='NM_004304.4', sampleId='P-0000004-T01-IM3', startPosition=29543736, studyId='msk_impact_2017', tumorAltCount=13, tumorRefCount=180, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='2', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=242793433, entrezGeneId=5133, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=5133, geneticEntityId=None, hugoGeneSymbol='PDCD1', type='protein-coding'), keyword='PDCD1 A215 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='A215V', proteinPosEnd=215, proteinPosStart=215, referenceAllele='G', refseqMrnaId='NM_005018.2', sampleId='P-0000004-T01-IM3', startPosition=242793433, studyId='msk_impact_2017', tumorAltCount=15, tumorRefCount=225, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='5', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=180030313, entrezGeneId=2324, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=2324, geneticEntityId=None, hugoGeneSymbol='FLT4', type='protein-coding'), keyword='FLT4 R1324 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='R1324L', proteinPosEnd=1324, proteinPosStart=1324, referenceAllele='C', refseqMrnaId='NM_182925.4', sampleId='P-0000004-T01-IM3', startPosition=180030313, studyId='msk_impact_2017', tumorAltCount=25, tumorRefCount=360, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='6', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=32188823, entrezGeneId=4855, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=4855, geneticEntityId=None, hugoGeneSymbol='NOTCH4', type='protein-coding'), keyword='NOTCH4 S244 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='S244L', proteinPosEnd=244, proteinPosStart=244, referenceAllele='G', refseqMrnaId='NM_004557.3', sampleId='P-0000004-T01-IM3', startPosition=32188823, studyId='msk_impact_2017', tumorAltCount=11, tumorRefCount=207, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='12', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=49433883, entrezGeneId=8085, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=8085, geneticEntityId=None, hugoGeneSymbol='KMT2D', type='protein-coding'), keyword='KMT2D P2557 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='P2557L', proteinPosEnd=2557, proteinPosStart=2557, referenceAllele='G', refseqMrnaId='NM_003482.3', sampleId='P-0000004-T01-IM3', startPosition=49433883, studyId='msk_impact_2017', tumorAltCount=16, tumorRefCount=247, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='14', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=81422178, entrezGeneId=7253, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=7253, geneticEntityId=None, hugoGeneSymbol='TSHR', type='protein-coding'), keyword='TSHR P52 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='P52T', proteinPosEnd=52, proteinPosStart=52, referenceAllele='C', refseqMrnaId='NM_000369.2', sampleId='P-0000004-T01-IM3', startPosition=81422178, studyId='msk_impact_2017', tumorAltCount=13, tumorRefCount=195, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='16', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=2110795, entrezGeneId=7249, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=7249, geneticEntityId=None, hugoGeneSymbol='TSC2', type='protein-coding'), keyword='TSC2 R367 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000004', proteinChange='R367Q', proteinPosEnd=367, proteinPosStart=367, referenceAllele='G', refseqMrnaId='NM_000548.3', sampleId='P-0000004-T01-IM3', startPosition=2110795, studyId='msk_impact_2017', tumorAltCount=22, tumorRefCount=236, uniquePatientKey='UC0wMDAwMDA0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDA0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='3', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=178936091, entrezGeneId=5290, fisValue=1.62, functionalImpactScore='L', gene=Gene(entrezGeneId=5290, geneticEntityId=None, hugoGeneSymbol='PIK3CA', type='protein-coding'), keyword='PIK3CA E545 missense', linkMsa='getma.org/?cm=msa&ty=f&p=PK3CA_HUMAN&rb=519&re=704&var=E545K', linkPdb='getma.org/pdb.php?prot=PK3CA_HUMAN&from=519&to=704&var=E545K', linkXvar='getma.org/?cm=var&var=hg19,3,178936091,G,A&fts=all', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000015', proteinChange='E545K', proteinPosEnd=545, proteinPosStart=545, referenceAllele='G', refseqMrnaId='NM_006218.2', sampleId='P-0000015-T01-IM3', startPosition=178936091, studyId='msk_impact_2017', tumorAltCount=56, tumorRefCount=80, uniquePatientKey='UC0wMDAwMDE1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDE1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=7577539, entrezGeneId=7157, fisValue=3.28, functionalImpactScore='M', gene=Gene(entrezGeneId=7157, geneticEntityId=None, hugoGeneSymbol='TP53', type='protein-coding'), keyword='TP53 R248 missense', linkMsa='http://mutationassessor.org/r3/?cm=msa&ty=f&p=P53_HUMAN&rb=95&re=289&var=R248W', linkPdb='http://mutationassessor.org/r3/pdb.php?prot=P53_HUMAN&from=95&to=289&var=R248W', linkXvar='R248W', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000015', proteinChange='R248W', proteinPosEnd=248, proteinPosStart=248, referenceAllele='G', refseqMrnaId='NM_001126112.2', sampleId='P-0000015-T01-IM3', startPosition=7577539, studyId='msk_impact_2017', tumorAltCount=61, tumorRefCount=131, uniquePatientKey='UC0wMDAwMDE1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDE1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='10', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=8111514, entrezGeneId=2625, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=2625, geneticEntityId=None, hugoGeneSymbol='GATA3', type='protein-coding'), keyword='GATA3 truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Ins', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000015', proteinChange='D335Gfs*17', proteinPosEnd=335, proteinPosStart=333, referenceAllele='-', refseqMrnaId='NA', sampleId='P-0000015-T01-IM3', startPosition=8111513, studyId='msk_impact_2017', tumorAltCount=75, tumorRefCount=378, uniquePatientKey='UC0wMDAwMDE1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDE1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='INS'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='6', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=152419920, entrezGeneId=2099, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=2099, geneticEntityId=None, hugoGeneSymbol='ESR1', type='protein-coding'), keyword='ESR1 L536 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000015', proteinChange='L536H', proteinPosEnd=536, proteinPosStart=536, referenceAllele='T', refseqMrnaId='NM_000125.3', sampleId='P-0000015-T01-IM3', startPosition=152419920, studyId='msk_impact_2017', tumorAltCount=45, tumorRefCount=78, uniquePatientKey='UC0wMDAwMDE1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDE1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='2', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=29450535, entrezGeneId=238, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=238, geneticEntityId=None, hugoGeneSymbol='ALK', type='protein-coding'), keyword='ALK G940 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000015', proteinChange='G940D', proteinPosEnd=940, proteinPosStart=940, referenceAllele='C', refseqMrnaId='NM_004304.4', sampleId='P-0000015-T01-IM3', startPosition=29450535, studyId='msk_impact_2017', tumorAltCount=47, tumorRefCount=196, uniquePatientKey='UC0wMDAwMDE1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDE1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='12', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=58144485, entrezGeneId=1019, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=1019, geneticEntityId=None, hugoGeneSymbol='CDK4', type='protein-coding'), keyword='CDK4 D196 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000015', proteinChange='D196H', proteinPosEnd=196, proteinPosStart=196, referenceAllele='C', refseqMrnaId='NM_000075.3', sampleId='P-0000015-T01-IM3', startPosition=58144485, studyId='msk_impact_2017', tumorAltCount=84, tumorRefCount=346, uniquePatientKey='UC0wMDAwMDE1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDE1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=56440637, entrezGeneId=54894, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=54894, geneticEntityId=None, hugoGeneSymbol='RNF43', type='protein-coding'), keyword='RNF43 W194 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000015', proteinChange='W194S', proteinPosEnd=194, proteinPosStart=194, referenceAllele='C', refseqMrnaId='NA', sampleId='P-0000015-T01-IM3', startPosition=56440637, studyId='msk_impact_2017', tumorAltCount=79, tumorRefCount=775, uniquePatientKey='UC0wMDAwMDE1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDE1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='21', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=44514647, entrezGeneId=7307, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=7307, geneticEntityId=None, hugoGeneSymbol='U2AF1', type='protein-coding'), keyword='U2AF1 N170 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000023', proteinChange='N170S', proteinPosEnd=170, proteinPosStart=170, referenceAllele='T', refseqMrnaId='NM_006758.2', sampleId='P-0000023-T01-IM3', startPosition=44514647, studyId='msk_impact_2017', tumorAltCount=60, tumorRefCount=291, uniquePatientKey='UC0wMDAwMDIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='6', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=150023076, entrezGeneId=9113, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=9113, geneticEntityId=None, hugoGeneSymbol='LATS1', type='protein-coding'), keyword='LATS1 truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Nonsense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000023', proteinChange='R63*', proteinPosEnd=63, proteinPosStart=63, referenceAllele='G', refseqMrnaId='NA', sampleId='P-0000023-T01-IM3', startPosition=150023076, studyId='msk_impact_2017', tumorAltCount=38, tumorRefCount=511, uniquePatientKey='UC0wMDAwMDIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='13', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=21555732, entrezGeneId=26524, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=26524, geneticEntityId=None, hugoGeneSymbol='LATS2', type='protein-coding'), keyword='LATS2 truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Ins', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000023', proteinChange='N847*', proteinPosEnd=847, proteinPosStart=846, referenceAllele='-', refseqMrnaId='NM_014572.2', sampleId='P-0000023-T01-IM3', startPosition=21555731, studyId='msk_impact_2017', tumorAltCount=119, tumorRefCount=232, uniquePatientKey='UC0wMDAwMDIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='INS'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='6', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=150001256, entrezGeneId=9113, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=9113, geneticEntityId=None, hugoGeneSymbol='LATS1', type='protein-coding'), keyword='LATS1 D783 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000023', proteinChange='D783V', proteinPosEnd=783, proteinPosStart=783, referenceAllele='T', refseqMrnaId='NA', sampleId='P-0000023-T01-IM3', startPosition=150001256, studyId='msk_impact_2017', tumorAltCount=91, tumorRefCount=440, uniquePatientKey='UC0wMDAwMDIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='3', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=52439259, entrezGeneId=8314, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=8314, geneticEntityId=None, hugoGeneSymbol='BAP1', type='protein-coding'), keyword='BAP1 truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Del', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000023', proteinChange='P328Lfs*7', proteinPosEnd=328, proteinPosStart=328, referenceAllele='G', refseqMrnaId='NM_004656.3', sampleId='P-0000023-T01-IM3', startPosition=52439259, studyId='msk_impact_2017', tumorAltCount=60, tumorRefCount=179, uniquePatientKey='UC0wMDAwMDIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='10', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=89720721, entrezGeneId=5728, fisValue=1.4013e-45, functionalImpactScore='NA', gene=Gene(entrezGeneId=5728, geneticEntityId=None, hugoGeneSymbol='PTEN', type='protein-coding'), keyword='PTEN truncating', linkMsa='NA', linkPdb='NA', linkXvar='NA', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Ins', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000024', proteinChange='N292Kfs*6', proteinPosEnd=292, proteinPosStart=291, referenceAllele='-', refseqMrnaId='NM_000314.4', sampleId='P-0000024-T01-IM3', startPosition=89720720, studyId='msk_impact_2017', tumorAltCount=53, tumorRefCount=170, uniquePatientKey='UC0wMDAwMDI0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='INS'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='10', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=89692904, entrezGeneId=5728, fisValue=4.165, functionalImpactScore='H', gene=Gene(entrezGeneId=5728, geneticEntityId=None, hugoGeneSymbol='PTEN', type='protein-coding'), keyword='PTEN R130 missense', linkMsa='http://mutationassessor.org/r3/?cm=msa&ty=f&p=PTEN_HUMAN&rb=45&re=171&var=R130G', linkPdb='http://mutationassessor.org/r3/pdb.php?prot=PTEN_HUMAN&from=45&to=171&var=R130G', linkXvar='R130G', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000024', proteinChange='R130G', proteinPosEnd=130, proteinPosStart=130, referenceAllele='C', refseqMrnaId='NM_000314.4', sampleId='P-0000024-T01-IM3', startPosition=89692904, studyId='msk_impact_2017', tumorAltCount=231, tumorRefCount=846, uniquePatientKey='UC0wMDAwMDI0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='23', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=39921444, entrezGeneId=54880, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=54880, geneticEntityId=None, hugoGeneSymbol='BCOR', type='protein-coding'), keyword='BCOR N1459 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000024', proteinChange='N1459S', proteinPosEnd=1459, proteinPosStart=1459, referenceAllele='T', refseqMrnaId='NM_001123385.1', sampleId='P-0000024-T01-IM3', startPosition=39921444, studyId='msk_impact_2017', tumorAltCount=317, tumorRefCount=647, uniquePatientKey='UC0wMDAwMDI0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='3', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=41266113, entrezGeneId=1499, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=1499, geneticEntityId=None, hugoGeneSymbol='CTNNB1', type='protein-coding'), keyword='CTNNB1 S37 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000024', proteinChange='S37Y', proteinPosEnd=37, proteinPosStart=37, referenceAllele='C', refseqMrnaId='NM_001904.3', sampleId='P-0000024-T01-IM3', startPosition=41266113, studyId='msk_impact_2017', tumorAltCount=280, tumorRefCount=965, uniquePatientKey='UC0wMDAwMDI0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='1', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=27105881, entrezGeneId=8289, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=8289, geneticEntityId=None, hugoGeneSymbol='ARID1A', type='protein-coding'), keyword='ARID1A truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Del', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000024', proteinChange='K1830Mfs*52', proteinPosEnd=1830, proteinPosStart=1830, referenceAllele='AGCT', refseqMrnaId='NM_006015.4', sampleId='P-0000024-T01-IM3', startPosition=27105878, studyId='msk_impact_2017', tumorAltCount=234, tumorRefCount=527, uniquePatientKey='UC0wMDAwMDI0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='5', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=67591248, entrezGeneId=5295, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=5295, geneticEntityId=None, hugoGeneSymbol='PIK3R1', type='protein-coding'), keyword='PIK3R1 truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Splice_Site', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000024', proteinChange='X582_splice', proteinPosEnd=582, proteinPosStart=582, referenceAllele='TGTTTTTCAGG', refseqMrnaId='NA', sampleId='P-0000024-T01-IM3', startPosition=67591238, studyId='msk_impact_2017', tumorAltCount=445, tumorRefCount=762, uniquePatientKey='UC0wMDAwMDI0Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI0LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='3', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=178916924, entrezGeneId=5290, fisValue=2.14, functionalImpactScore='M', gene=Gene(entrezGeneId=5290, geneticEntityId=None, hugoGeneSymbol='PIK3CA', type='protein-coding'), keyword='PIK3CA P104 missense', linkMsa='http://mutationassessor.org/r3/?cm=msa&ty=f&p=PK3CA_HUMAN&rb=31&re=108&var=P104L', linkPdb='http://mutationassessor.org/r3/pdb.php?prot=PK3CA_HUMAN&from=31&to=108&var=P104L', linkXvar='P104L', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000025', proteinChange='P104L', proteinPosEnd=104, proteinPosStart=104, referenceAllele='C', refseqMrnaId='NM_006218.2', sampleId='P-0000025-T02-IM5', startPosition=178916924, studyId='msk_impact_2017', tumorAltCount=269, tumorRefCount=1318, uniquePatientKey='UC0wMDAwMDI1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI1LVQwMi1JTTU6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=7577538, entrezGeneId=7157, fisValue=1.4013e-45, functionalImpactScore='NA', gene=Gene(entrezGeneId=7157, geneticEntityId=None, hugoGeneSymbol='TP53', type='protein-coding'), keyword='TP53 R248 missense', linkMsa='NA', linkPdb='NA', linkXvar='NA', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000025', proteinChange='R248Q', proteinPosEnd=248, proteinPosStart=248, referenceAllele='C', refseqMrnaId='NM_001126112.2', sampleId='P-0000025-T02-IM5', startPosition=7577538, studyId='msk_impact_2017', tumorAltCount=201, tumorRefCount=788, uniquePatientKey='UC0wMDAwMDI1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI1LVQwMi1JTTU6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=7577538, entrezGeneId=7157, fisValue=1.4013e-45, functionalImpactScore='NA', gene=Gene(entrezGeneId=7157, geneticEntityId=None, hugoGeneSymbol='TP53', type='protein-coding'), keyword='TP53 R248 missense', linkMsa='NA', linkPdb='NA', linkXvar='NA', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000025', proteinChange='R248Q', proteinPosEnd=248, proteinPosStart=248, referenceAllele='C', refseqMrnaId='NM_001126112.2', sampleId='P-0000025-T01-IM3', startPosition=7577538, studyId='msk_impact_2017', tumorAltCount=49, tumorRefCount=827, uniquePatientKey='UC0wMDAwMDI1Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI1LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=7577538, entrezGeneId=7157, fisValue=1.4013e-45, functionalImpactScore='NA', gene=Gene(entrezGeneId=7157, geneticEntityId=None, hugoGeneSymbol='TP53', type='protein-coding'), keyword='TP53 R248 missense', linkMsa='NA', linkPdb='NA', linkXvar='NA', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000026', proteinChange='R248Q', proteinPosEnd=248, proteinPosStart=248, referenceAllele='C', refseqMrnaId='NM_001126112.2', sampleId='P-0000026-T01-IM3', startPosition=7577538, studyId='msk_impact_2017', tumorAltCount=370, tumorRefCount=261, uniquePatientKey='UC0wMDAwMDI2Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI2LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='3', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=178936094, entrezGeneId=5290, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=5290, geneticEntityId=None, hugoGeneSymbol='PIK3CA', type='protein-coding'), keyword='PIK3CA Q546 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000026', proteinChange='Q546K', proteinPosEnd=546, proteinPosStart=546, referenceAllele='C', refseqMrnaId='NM_006218.2', sampleId='P-0000026-T01-IM3', startPosition=178936094, studyId='msk_impact_2017', tumorAltCount=468, tumorRefCount=325, uniquePatientKey='UC0wMDAwMDI2Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI2LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='7', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=50467844, entrezGeneId=10320, fisValue=1.4013e-45, functionalImpactScore='NA', gene=Gene(entrezGeneId=10320, geneticEntityId=None, hugoGeneSymbol='IKZF1', type='protein-coding'), keyword='IKZF1 R360 missense', linkMsa='NA', linkPdb='NA', linkXvar='NA', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000026', proteinChange='R360H', proteinPosEnd=360, proteinPosStart=360, referenceAllele='G', refseqMrnaId='NM_006060.4', sampleId='P-0000026-T01-IM3', startPosition=50467844, studyId='msk_impact_2017', tumorAltCount=135, tumorRefCount=469, uniquePatientKey='UC0wMDAwMDI2Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI2LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='6', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=150004871, entrezGeneId=9113, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=9113, geneticEntityId=None, hugoGeneSymbol='LATS1', type='protein-coding'), keyword='LATS1 P452 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000026', proteinChange='P452A', proteinPosEnd=452, proteinPosStart=452, referenceAllele='G', refseqMrnaId='NA', sampleId='P-0000026-T01-IM3', startPosition=150004871, studyId='msk_impact_2017', tumorAltCount=109, tumorRefCount=716, uniquePatientKey='UC0wMDAwMDI2Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI2LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='5', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=1295228, entrezGeneId=7015, fisValue=1.4013e-45, functionalImpactScore='NA', gene=Gene(entrezGeneId=7015, geneticEntityId=None, hugoGeneSymbol='TERT', type='protein-coding'), keyword=None, linkMsa='NA', linkPdb='NA', linkXvar='NA', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType="5'Flank", namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000027', proteinChange='Promoter', proteinPosEnd=-1, proteinPosStart=-1, referenceAllele='G', refseqMrnaId='NM_198253.2', sampleId='P-0000027-T01-IM3', startPosition=1295228, studyId='msk_impact_2017', tumorAltCount=16, tumorRefCount=122, uniquePatientKey='UC0wMDAwMDI3Om1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDI3LVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='10', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=89711899, entrezGeneId=5728, fisValue=4.035, functionalImpactScore='H', gene=Gene(entrezGeneId=5728, geneticEntityId=None, hugoGeneSymbol='PTEN', type='protein-coding'), keyword='PTEN R173 missense', linkMsa='http://mutationassessor.org/r3/?cm=msa&ty=f&p=PTEN_HUMAN&rb=14&re=185&var=R173C', linkPdb='http://mutationassessor.org/r3/pdb.php?prot=PTEN_HUMAN&from=14&to=185&var=R173C', linkXvar='R173C', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000030', proteinChange='R173C', proteinPosEnd=173, proteinPosStart=173, referenceAllele='C', refseqMrnaId='NM_000314.4', sampleId='P-0000030-T01-IM3', startPosition=89711899, studyId='msk_impact_2017', tumorAltCount=300, tumorRefCount=481, uniquePatientKey='UC0wMDAwMDMwOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDMwLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=7578223, entrezGeneId=7157, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=7157, geneticEntityId=None, hugoGeneSymbol='TP53', type='protein-coding'), keyword='TP53 truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Del', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000030', proteinChange='R209Kfs*6', proteinPosEnd=209, proteinPosStart=209, referenceAllele='TC', refseqMrnaId='NM_001126112.2', sampleId='P-0000030-T01-IM3', startPosition=7578222, studyId='msk_impact_2017', tumorAltCount=216, tumorRefCount=416, uniquePatientKey='UC0wMDAwMDMwOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMDMwLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
# ...
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='5', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=149505028, entrezGeneId=5159, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=5159, geneticEntityId=None, hugoGeneSymbol='PDGFRB', type='protein-coding'), keyword='PDGFRB P596 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='P596R', proteinPosEnd=596, proteinPosStart=596, referenceAllele='G', refseqMrnaId='NM_002609.3', sampleId='P-0000222-T01-IM3', startPosition=149505028, studyId='msk_impact_2017', tumorAltCount=40, tumorRefCount=618, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='6', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=157099136, entrezGeneId=57492, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=57492, geneticEntityId=None, hugoGeneSymbol='ARID1B', type='protein-coding'), keyword='ARID1B L25 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='L25V', proteinPosEnd=25, proteinPosStart=25, referenceAllele='C', refseqMrnaId='NM_020732.3', sampleId='P-0000222-T01-IM3', startPosition=157099136, studyId='msk_impact_2017', tumorAltCount=21, tumorRefCount=253, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='7', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=151874550, entrezGeneId=58508, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=58508, geneticEntityId=None, hugoGeneSymbol='KMT2C', type='protein-coding'), keyword='KMT2C truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Nonsense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='S2663*', proteinPosEnd=2663, proteinPosStart=2663, referenceAllele='G', refseqMrnaId='NM_170606.2', sampleId='P-0000222-T01-IM3', startPosition=151874550, studyId='msk_impact_2017', tumorAltCount=66, tumorRefCount=1215, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='7', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=151919140, entrezGeneId=58508, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=58508, geneticEntityId=None, hugoGeneSymbol='KMT2C', type='protein-coding'), keyword='KMT2C D1149 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='D1149N', proteinPosEnd=1149, proteinPosStart=1149, referenceAllele='C', refseqMrnaId='NM_170606.2', sampleId='P-0000222-T01-IM3', startPosition=151919140, studyId='msk_impact_2017', tumorAltCount=242, tumorRefCount=814, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='9', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=139390892, entrezGeneId=4851, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=4851, geneticEntityId=None, hugoGeneSymbol='NOTCH1', type='protein-coding'), keyword='NOTCH1 F2433 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='F2433L', proteinPosEnd=2433, proteinPosStart=2433, referenceAllele='G', refseqMrnaId='NM_017617.3', sampleId='P-0000222-T01-IM3', startPosition=139390892, studyId='msk_impact_2017', tumorAltCount=40, tumorRefCount=298, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='12', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=4398124, entrezGeneId=894, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=894, geneticEntityId=None, hugoGeneSymbol='CCND2', type='protein-coding'), keyword='CCND2 E230 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='E230Q', proteinPosEnd=230, proteinPosStart=230, referenceAllele='G', refseqMrnaId='NM_001759.3', sampleId='P-0000222-T01-IM3', startPosition=4398124, studyId='msk_impact_2017', tumorAltCount=103, tumorRefCount=795, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='22', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=41564521, entrezGeneId=2033, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=2033, geneticEntityId=None, hugoGeneSymbol='EP300', type='protein-coding'), keyword='EP300 H1315 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='H1315D', proteinPosEnd=1315, proteinPosStart=1315, referenceAllele='C', refseqMrnaId='NM_001429.3', sampleId='P-0000222-T01-IM3', startPosition=41564521, studyId='msk_impact_2017', tumorAltCount=173, tumorRefCount=1281, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='4', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=55984910, entrezGeneId=3791, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=3791, geneticEntityId=None, hugoGeneSymbol='KDR', type='protein-coding'), keyword='KDR truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Del', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='R73Sfs*5', proteinPosEnd=73, proteinPosStart=73, referenceAllele='CC', refseqMrnaId='NM_002253.2', sampleId='P-0000222-T01-IM3', startPosition=55984909, studyId='msk_impact_2017', tumorAltCount=67, tumorRefCount=1215, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='5', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=1295228, entrezGeneId=7015, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=7015, geneticEntityId=None, hugoGeneSymbol='TERT', type='protein-coding'), keyword=None, linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType="5'Flank", namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000222', proteinChange='Promoter', proteinPosEnd=-1, proteinPosStart=-1, referenceAllele='GGGGCTGGGAGGGCCCGGAG', refseqMrnaId='NM_198253.2', sampleId='P-0000222-T01-IM3', startPosition=1295209, studyId='msk_impact_2017', tumorAltCount=17, tumorRefCount=95, uniquePatientKey='UC0wMDAwMjIyOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIyLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='17', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=7578208, entrezGeneId=7157, fisValue=2.43, functionalImpactScore='M', gene=Gene(entrezGeneId=7157, geneticEntityId=None, hugoGeneSymbol='TP53', type='protein-coding'), keyword='TP53 H214 missense', linkMsa='http://mutationassessor.org/r3/?cm=msa&ty=f&p=P53_HUMAN&rb=95&re=289&var=H214R', linkPdb='http://mutationassessor.org/r3/pdb.php?prot=P53_HUMAN&from=95&to=289&var=H214R', linkXvar='H214R', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000223', proteinChange='H214R', proteinPosEnd=214, proteinPosStart=214, referenceAllele='T', refseqMrnaId='NM_001126112.2', sampleId='P-0000223-T01-IM3', startPosition=7578208, studyId='msk_impact_2017', tumorAltCount=1461, tumorRefCount=124, uniquePatientKey='UC0wMDAwMjIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='C', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='2', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=209113113, entrezGeneId=3417, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=3417, geneticEntityId=None, hugoGeneSymbol='IDH1', type='protein-coding'), keyword='IDH1 R132 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000223', proteinChange='R132S', proteinPosEnd=132, proteinPosStart=132, referenceAllele='G', refseqMrnaId='NM_005896.2', sampleId='P-0000223-T01-IM3', startPosition=209113113, studyId='msk_impact_2017', tumorAltCount=551, tumorRefCount=716, uniquePatientKey='UC0wMDAwMjIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='T', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='23', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=76872187, entrezGeneId=546, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=546, geneticEntityId=None, hugoGeneSymbol='ATRX', type='protein-coding'), keyword='ATRX truncating', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Frame_Shift_Del', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000223', proteinChange='T1821Qfs*7', proteinPosEnd=1821, proteinPosStart=1820, referenceAllele='AGGCAAGAATTTTGTTAATGCTGTA', refseqMrnaId='NM_000489.3', sampleId='P-0000223-T01-IM3', startPosition=76872163, studyId='msk_impact_2017', tumorAltCount=221, tumorRefCount=671, uniquePatientKey='UC0wMDAwMjIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='-', variantType='DEL'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='4', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=187629296, entrezGeneId=2195, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=2195, geneticEntityId=None, hugoGeneSymbol='FAT1', type='protein-coding'), keyword='FAT1 L562 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000223', proteinChange='L562F', proteinPosEnd=562, proteinPosStart=562, referenceAllele='C', refseqMrnaId='NM_005245.3', sampleId='P-0000223-T01-IM3', startPosition=187629296, studyId='msk_impact_2017', tumorAltCount=177, tumorRefCount=1014, uniquePatientKey='UC0wMDAwMjIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='A', variantType='SNP'),
#  Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='NA', chr='23', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=44950106, entrezGeneId=7403, fisValue=1.4013e-45, functionalImpactScore='', gene=Gene(entrezGeneId=7403, geneticEntityId=None, hugoGeneSymbol='KDM6A', type='protein-coding'), keyword='KDM6A I1292 missense', linkMsa='', linkPdb='', linkXvar='', molecularProfileId='msk_impact_2017_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=None, normalRefCount=None, patientId='P-0000223', proteinChange='I1292S', proteinPosEnd=1292, proteinPosStart=1292, referenceAllele='T', refseqMrnaId='NM_021140.2', sampleId='P-0000223-T01-IM3', startPosition=44950106, studyId='msk_impact_2017', tumorAltCount=344, tumorRefCount=804, uniquePatientKey='UC0wMDAwMjIzOm1za19pbXBhY3RfMjAxNw', uniqueSampleKey='UC0wMDAwMjIzLVQwMS1JTTM6bXNrX2ltcGFjdF8yMDE3', validationStatus='NA', variantAllele='G', variantType='SNP'),
#  ...]
