# %%
import pandas as pd
import httplib2 as http
import json

try:
    from urlparse import urlparse
except ImportError:
    from urllib.parse import urlparse

# %%
gene = "NF1"
uri = 'https://dgidb.org'
path = f'/api/v2/interactions.json?genes={gene}'

target = urlparse(uri+path)
method = 'GET'
body = ''
headers = {
'Accept': 'application/json',
}

h = http.Http()

response, content = h.request(
target.geturl(),
method,
body,
headers)
data = json.loads(content)

# %%
data
# Out:
# {'matchedTerms': [{'searchTerm': 'NF1',
#    'geneName': 'NF1',
#    'geneLongName': 'NEUROFIBROMIN 1',
#    'entrezId': 4763,
#    'geneCategories': [{'id': '655bedfa9d71482796a5a34b87dfb297',
#      'name': 'DRUG RESISTANCE'},
#     {'id': '0d157beb-fd17-404d-8755-3a81aa5ed704',
#      'name': 'CLINICALLY ACTIONABLE'}],
#    'interactions': [{'interactionId': 'c9fce773-9cdd-4d91-b8d6-a3e1bf1fced3',
#      'interactionTypes': [],
#      'drugName': 'BINIMETINIB',
#      'drugConceptId': 'chembl:CHEMBL3187723',
#      'sources': ['ClearityFoundationBiomarkers', 'CIViC'],
#      'pmids': [26925841],
#      'score': 1.29},
#     {'interactionId': '6daace60-8e57-4bf0-9373-c8e3c7448c75',
#      'interactionTypes': [],
#      'drugName': 'SELUMETINIB',
#      'drugConceptId': 'chembl:CHEMBL1614701',
#      'sources': ['ClearityFoundationBiomarkers', 'CIViC'],
#      'pmids': [28029918, 31151904],
#      'score': 0.88},
#     {'interactionId': 'd2cbb163-04c7-441e-b2fa-9649222b1bf9',
#      'interactionTypes': [],
#      'drugName': 'TRAMETINIB',
#      'drugConceptId': 'chembl:CHEMBL2103875',
#      'sources': ['ClearityFoundationBiomarkers', 'CIViC', 'OncoKB'],
#      'pmids': [24576830, 29127119, 2524381],
#      'score': 1.1},
#     {'interactionId': '07cf8e90-8ba5-4e44-a0e8-634d73ababeb',
#      'interactionTypes': [],
#      'drugName': 'VEMURAFENIB',
#      'drugConceptId': 'chembl:CHEMBL1229517',
#      'sources': ['CIViC'],
#      'pmids': [23288408, 231718],
#      'score': 0.8},
#     {'interactionId': 'a15f0550-96a9-42be-9333-435115e7165d',
#      'interactionTypes': [],
#      'drugName': 'SIROLIMUS',
#      'drugConceptId': 'chembl:CHEMBL413',
#      'sources': ['CIViC'],
#      'pmids': [23171796],
#      'score': 0.28},
#     {'interactionId': 'a5efc46b-499e-4c9c-8903-60ac24ed12f1',
#      'interactionTypes': [],
#      'drugName': 'COBIMETINIB',
#      'drugConceptId': 'chembl:CHEMBL2146883',
#      'sources': ['ClearityFoundationBiomarkers', 'OncoKB'],
#      'pmids': [],
#      'score': 1.1},
#     {'interactionId': '9a43e6cd-a875-4cb2-be25-9f6314fde8f8',
#      'interactionTypes': [],
#      'drugName': 'PIMASERTIB',
#      'drugConceptId': 'chembl:CHEMBL2107832',
#      'sources': ['ClearityFoundationBiomarkers'],
#      'pmids': [],
#      'score': 0.86},
#     {'interactionId': 'f884e97c-5f42-45d2-9667-4d07af04bf8d',
#      'interactionTypes': [],
#      'drugName': 'DABRAFENIB',
#      'drugConceptId': 'chembl:CHEMBL2028663',
#      'sources': ['CIViC'],
#      'pmids': [23171796],
#      'score': 0.81}]}],
#  'ambiguousTerms': [],
#  'unmatchedTerms': []}

# %%
https://dgidb.org/api/v2/drugs/<concept_id>

# %%
concept_id = "chembl:CHEMBL2028663"
uri = 'https://dgidb.org'
path = f'/api/v2/drugs/{concept_id}'

target = urlparse(uri+path)
method = 'GET'
body = ''
headers = {
'Accept': 'application/json',
}

h = http.Http()

response, content = h.request(
target.geturl(),
method,
body,
headers)
data = json.loads(content)

# %%
data
# Out:
# {'name': 'DABRAFENIB',
#  'concept_id': 'chembl:CHEMBL2028663',
#  'approved': True,
#  'immunotherapy': False,
#  'anti_neoplastic': True,
#  'alias': ['GSK2118436A',
#   'DABRAFENIB',
#   'TAFINLAR',
#   'GSK-2118436A',
#   'GSK-2118436',
#   'GSK2118436',
#   'TAFINLAR®',
#   'DRB436',
#   'rxcui:1424911',
#   'pubchem.compound:44462760',
#   'drugbank:08912',
#   'chemidplus:1195765-45-7',
#   'chembl:CHEMBL2028663'],
#  'pmids': [28512244,
#   26392102,
#   26811525,
#   27500726,
#   27659046,
#   27770002,
#   22608338,
#   26732095,
#   27255157,
#   25265492,
#   28891408,
#   24265153,
#   24265154,
#   27080216,
#   27048246,
#   27697975,
#   28784858,
#   28268064,
#   22735384,
#   24885690,
#   27312529,
#   22389471,
#   27797976,
#   25370473,
#   27523909,
#   24265155,
#   25452114,
#   25673644,
#   25265494,
#   23031422,
#   29072975,
#   23020132,
#   29431699,
#   25435907,
#   28078132,
#   28480077,
#   25399551,
#   27283860,
#   24583796,
#   23463675,
#   23621583,
#   25656898,
#   22038996,
#   19773371,
#   23845441,
#   14679157,
#   22180495,
#   21156289,
#   21663470,
#   22356324,
#   12460918,
#   18541894,
#   23406027,
#   21129611,
#   22536370,
#   23470635,
#   23251002,
#   24594804,
#   19018267,
#   22586120,
#   23325582,
#   24388723,
#   19010912,
#   24508103,
#   20857202,
#   19537845,
#   21975775,
#   26678033,
#   22448344,
#   25024077,
#   20350999,
#   24163374,
#   19561230,
#   20619739,
#   19255327,
#   22351686,
#   22048237,
#   23833300,
#   24576830,
#   22997239,
#   19238210,
#   23524406,
#   22281684,
#   19404918,
#   25370471,
#   24570209,
#   23612012,
#   20630094,
#   23489023,
#   21426297,
#   21639808,
#   20413299,
#   23812671,
#   23614898,
#   22649091,
#   22972589,
#   24396464,
#   20368568,
#   19001320,
#   24107445,
#   22241789,
#   26619011,
#   24586605,
#   23918947,
#   21163703,
#   24354346,
#   21594703,
#   15035987,
#   22663011,
#   23549875,
#   21683865,
#   22805292,
#   23934108,
#   25157968,
#   25989278,
#   20818844,
#   22773810,
#   21483012,
#   12460919,
#   22743296,
#   12068308,
#   38,
#   2014,
#   8009,
#   2013,
#   8006,
#   2015,
#   31811016,
#   28947956,
#   25056119,
#   27023328,
#   24463458,
#   23171796,
#   27135738,
#   28178529],
#  'attributes': [{'name': 'Pharmaceutical Developer',
#    'value': 'GlaxoSmithKline',
#    'sources': ['CancerCommons']},
#   {'name': 'Source Reported Drug Name(s)',
#    'value': 'Dabrafenib/GSK2118436',
#    'sources': ['CancerCommons']},
#   {'name': 'Drug Class',
#    'value': 'RAF Inhibitor',
#    'sources': ['CancerCommons']},
#   {'name': 'FDA Approval',
#    'value': 'Melanoma (with BRAF V600 mutation)',
#    'sources': ['MyCancerGenome']},
#   {'name': 'Drug Class',
#    'value': 'Kinase Inhibitors',
#    'sources': ['MyCancerGenome']},
#   {'name': 'FDA Approval',
#    'value': 'not approved',
#    'sources': ['TdgClinicalTrial']},
#   {'name': 'Drug Class',
#    'value': 'Small molecule',
#    'sources': ['TdgClinicalTrial']},
#   {'name': 'Drug Indications',
#    'value': 'antineoplastic agent',
#    'sources': ['TdgClinicalTrial']}],
#  'drug_claims': [{'source': 'ChemblDrugs',
#    'name': 'chembl:CHEMBL2028663',
#    'primary_name': 'DABRAFENIB',
#    'aliases': [],
#    'attributes': [],
#    'publications': []},
#   {'source': 'CancerCommons',
#    'name': 'DABRAFENIB',
#    'primary_name': 'DABRAFENIB',
#    'aliases': ['44462760', 'Dabrafenib', 'Dabrafenib'],
#    'attributes': [{'name': 'Drug Class', 'value': 'RAF Inhibitor'},
#     {'name': 'Source Reported Drug Name(s)', 'value': 'Dabrafenib/GSK2118436'},
#     {'name': 'Pharmaceutical Developer', 'value': 'GlaxoSmithKline'}],
#    'publications': []},
#   {'source': 'MyCancerGenomeClinicalTrial',
#    'name': 'GSK2118436',
#    'primary_name': 'GSK2118436',
#    'aliases': [],
#    'attributes': [],
#    'publications': []},
#   {'source': 'MyCancerGenome',
#    'name': 'DABRAFENIB',
#    'primary_name': 'DABRAFENIB',
#    'aliases': ['DABRAFENIB'],
#    'attributes': [{'name': 'Drug Class', 'value': 'Kinase Inhibitors'},
#     {'name': 'FDA Approval', 'value': 'Melanoma (with BRAF V600 mutation)'}],
#    'publications': []},
#   {'source': 'JAX-CKB',
#    'name': 'Dabrafenib',
#    'primary_name': 'Dabrafenib',
#    'aliases': [],
#    'attributes': [],
#    'publications': [25370473,
#     24265153,
#     22389471,
#     27312529,
#     24463458,
#     24265154,
#     27797976,
#     22608338,
#     27659046,
#     27255157,
#     28268064,
#     28512244,
#     27770002,
#     26732095,
#     27500726,
#     27523909,
#     26811525,
#     27048246,
#     25265492,
#     22735384,
#     27697975,
#     26392102,
#     28784858,
#     24885690,
#     28891408,
#     27080216]},
#   {'source': 'DoCM',
#    'name': 'DABRAFENIB',
#    'primary_name': 'DABRAFENIB',
#    'aliases': [],
#    'attributes': [],
#    'publications': [23020132,
#     22608338,
#     26619011,
#     21483012,
#     22351686,
#     19001320,
#     21156289,
#     20368568,
#     19255327,
#     22048237,
#     19561230,
#     19010912,
#     23549875,
#     25024077,
#     23489023,
#     18541894,
#     24586605,
#     24508103,
#     22773810,
#     23833300,
#     23812671,
#     24576830,
#     19238210,
#     20818844,
#     23612012,
#     23251002,
#     22356324,
#     20857202,
#     22536370,
#     22997239,
#     21163703,
#     15035987,
#     23470635,
#     21663470,
#     24594804,
#     22586120,
#     20413299,
#     22805292,
#     19537845,
#     14679157,
#     22663011,
#     21975775,
#     22038996,
#     22448344,
#     12068308,
#     24163374,
#     19773371,
#     24354346,
#     23325582,
#     24583796,
#     23031422,
#     22735384,
#     21683865,
#     25370471,
#     21639808,
#     22281684,
#     22649091,
#     22241789,
#     24570209,
#     23918947,
#     25989278,
#     22389471,
#     23934108,
#     22180495,
#     23524406,
#     26678033,
#     19018267,
#     24388723,
#     23845441,
#     23614898,
#     25157968,
#     20619739,
#     12460919,
#     24107445,
#     12460918,
#     21594703,
#     20350999,
#     20630094,
#     21426297,
#     19404918,
#     22743296,
#     24396464,
#     22972589,
#     21129611,
#     23406027,
#     25656898]},
#   {'source': 'TALC',
#    'name': 'DABRAFENIB',
#    'primary_name': 'DABRAFENIB',
#    'aliases': ['DABRAFENIB', 'DABRAFENIB', 'TAFINLAR'],
#    'attributes': [],
#    'publications': []},
#   {'source': 'TdgClinicalTrial',
#    'name': 'GSK2118436',
#    'primary_name': 'GSK2118436',
#    'aliases': [],
#    'attributes': [{'name': 'Drug Indications',
#      'value': 'antineoplastic agent'},
#     {'name': 'Drug Class', 'value': 'Small molecule'},
#     {'name': 'FDA Approval', 'value': 'not approved'}],
#    'publications': []},
#   {'source': 'OncoKB',
#    'name': 'Dabrafenib',
#    'primary_name': 'Dabrafenib',
#    'aliases': [],
#    'attributes': [],
#    'publications': []},
#   {'source': 'PharmGKB',
#    'name': 'dabrafenib',
#    'primary_name': 'dabrafenib',
#    'aliases': [],
#    'attributes': [],
#    'publications': [27023328]},
#   {'source': 'TTD',
#    'name': 'Dabrafenib',
#    'primary_name': 'Dabrafenib',
#    'aliases': ['D05ROI'],
#    'attributes': [],
#    'publications': []},
#   {'source': 'FDA',
#    'name': 'Dabrafenib',
#    'primary_name': 'Dabrafenib',
#    'aliases': [],
#    'attributes': [],
#    'publications': []},
#   {'source': 'COSMIC',
#    'name': 'Dabrafenib',
#    'primary_name': 'Dabrafenib',
#    'aliases': [],
#    'attributes': [],
#    'publications': []},
#   {'source': 'CIViC',
#    'name': 'DABRAFENIB',
#    'primary_name': 'DABRAFENIB',
#    'aliases': [],
#    'attributes': [],
#    'publications': [24265153,
#     25673644,
#     24265155,
#     23171796,
#     27135738,
#     25452114,
#     25056119,
#     23020132,
#     22608338,
#     29072975,
#     25399551,
#     23463675,
#     25265494,
#     31811016,
#     27283860,
#     27048246,
#     24583796,
#     23031422,
#     25265492,
#     25435907,
#     28947956,
#     28480077,
#     28891408,
#     29431699,
#     28078132,
#     28178529]}]}

# %%
/fields

# %%
# Out:
# {'version': '6.8',
#  'hitCount': 24089,
#  'nextCursorMark': 'AoIIQE+8Ryg0Njc0MTEzMw==',
#  'nextPageUrl': 'https://www.ebi.ac.uk/europepmc/webservices/rest/search?query=NF1&cursorMark=AoIIQE+8Ryg0Njc0MTEzMw==&resultType=lite&format=json',
#  'request': {'queryString': 'NF1',
#   'resultType': 'lite',
#   'cursorMark': '*',
#   'pageSize': 25,
#   'sort': '',
#   'synonym': False},
#  'resultList': {'result': [{'id': '35933588',
#     'source': 'MED',
#     'pmid': '35933588',
#     'doi': '10.1002/rcm.9374',
#     'title': 'New insights into pathogenesis of congenital pseudarthrosis of tibia in children using periosteum proteomics analysis.',
#     'authorString': 'Liu Y, Qin ZQ, Zheng Y, Wu J, Yang G, Tan Q, Zhu G, Liu K, Mei H.',
#     'journalTitle': 'Rapid Commun Mass Spectrom',
#     'issue': '21',
#     'journalVolume': '36',
#     'pubYear': '2022',
#     'journalIssn': '0951-4198; 1097-0231; ',
#     'pageInfo': 'e9374',
#     'pubType': 'journal article',
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-08-07',
#     'firstPublicationDate': '2022-11-01'},
#    {'id': '36215287',
#     'source': 'MED',
#     'pmid': '36215287',
#     'pmcid': 'PMC9551631',
#     'fullTextIdList': {'fullTextId': ['PMC9551631']},
#     'doi': '10.1371/journal.pone.0275803',
#     'title': 'Cognitive and behavioral functioning in two neurogenetic disorders; how different are these aspects in Duchenne muscular dystrophy and Neurofibromatosis type 1?',
#     'authorString': 'Hellebrekers DMJ, van Abeelen SAM, Catsman CE, van Kuijk SMJ, Laridon AM, Klinkenberg S, Hendriksen JGM, Vles JSH.',
#     'journalTitle': 'PLoS One',
#     'issue': '10',
#     'journalVolume': '17',
#     'pubYear': '2022',
#     'journalIssn': '1932-6203',
#     'pageInfo': 'e0275803',
#     'pubType': 'research-article; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'Y',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-10-11',
#     'firstPublicationDate': '2022-10-10'},
#    {'id': '36127120',
#     'source': 'MED',
#     'pmid': '36127120',
#     'pmcid': 'PMC9490603',
#     'fullTextIdList': {'fullTextId': ['PMC9490603']},
#     'doi': '10.1136/bmjopen-2022-065340',
#     'title': 'Cohort profile: life with neurofibromatosis 1 - the Danish NF1 cohort.',
#     'authorString': 'Doser K, Hove H, Østergaard JR, Bidstrup PE, Dalton SO, Handrup MM, Ejerskov C, Krøyer A, Doherty MA, Møllegaard Jepsen JR, Mulvihill JJ, Winther JF, Kenborg L.',
#     'journalTitle': 'BMJ Open',
#     'issue': '9',
#     'journalVolume': '12',
#     'pubYear': '2022',
#     'journalIssn': '2044-6055',
#     'pageInfo': 'e065340',
#     'pubType': "research support, non-u.s. gov't; research-article; research support, u.s. gov't, non-p.h.s.; journal article",
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'Y',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-23',
#     'firstPublicationDate': '2022-09-20'},
#    {'id': 'PMC9543027',
#     'source': 'PMC',
#     'pmcid': 'PMC9543027',
#     'fullTextIdList': {'fullTextId': ['PMC9543027']},
#     'title': 'Vertebral arteriovenous fistulae (AVF) and vertebral artery aneurysms in neurofibromatosis type 1: A case report and a systematic review',
#     'authorString': 'Zhao J, Zhao G, Lu L, Li C, Yang R.',
#     'journalTitle': 'Medicine (Baltimore)',
#     'issue': '40',
#     'journalVolume': '101',
#     'pubYear': '2022',
#     'journalIssn': '0304-5412; 1536-5964; 0025-7974; ',
#     'pubType': 'research-article; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'Y',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'N',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'N',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-10-13',
#     'firstPublicationDate': '2022-10-07'},
#    {'id': 'PPR547294',
#     'source': 'PPR',
#     'doi': '10.1101/2022.09.15.508161',
#     'title': 'Neurofibromin 1 mediates sleep depth in <i>Drosophila</i>',
#     'authorString': 'Brown EB, Zhang J, Lloyd E, Lanzon E, Botero V, Tomchik S, Keene AC.',
#     'pubYear': '2022',
#     'pubType': 'preprint',
#     'bookOrReportDetails': {'publisher': 'bioRxiv', 'yearOfPublication': 2022},
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-21',
#     'firstPublicationDate': '2022-09-19'},
#    {'id': '36064430',
#     'source': 'MED',
#     'pmid': '36064430',
#     'pmcid': 'PMC9446792',
#     'fullTextIdList': {'fullTextId': ['PMC9446792']},
#     'doi': '10.1186/s13023-022-02482-8',
#     'title': 'Head circumference and anthropometric changes and their relation to plexiform and skin neurofibromas in sporadic and familial neurofibromatosis 1 Brazilian adults: a cross-sectional study.',
#     'authorString': 'Basto DL, de Souza Vieira G, Andrade-Losso RM, Almeida PN, Riccardi VM, Rozza-de-Menezes RE, Cunha KS.',
#     'journalTitle': 'Orphanet J Rare Dis',
#     'issue': '1',
#     'journalVolume': '17',
#     'pubYear': '2022',
#     'journalIssn': '1750-1172',
#     'pageInfo': '341',
#     'pubType': 'research-article; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'Y',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-06',
#     'firstPublicationDate': '2022-09-05'},
#    {'id': 'PMC9555059',
#     'source': 'PMC',
#     'pmcid': 'PMC9555059',
#     'fullTextIdList': {'fullTextId': ['PMC9555059']},
#     'title': 'Efficacy of different salvage regimens in progressive unresectable pediatric low-grade glioma',
#     'authorString': 'El-Hemaly A, Taha H, Refaat A, Adel F, Elbeltagy M, Arafah O.',
#     'journalTitle': 'Oncology Letters',
#     'issue': '5',
#     'journalVolume': '24',
#     'pubYear': '2022',
#     'journalIssn': '1792-1074',
#     'pubType': 'research-article; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'Y',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'N',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'N',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-10-15',
#     'firstPublicationDate': '2022-09-26'},
#    {'id': '36221365',
#     'source': 'MED',
#     'pmid': '36221365',
#     'doi': '10.1097/md.0000000000030952',
#     'title': 'Vertebral arteriovenous fistulae (AVF) and vertebral artery aneurysms in neurofibromatosis type 1: A case report and a systematic review.',
#     'authorString': 'Zhao J, Zhao G, Lu L, Li C, Yang R.',
#     'journalTitle': 'Medicine (Baltimore)',
#     'issue': '40',
#     'journalVolume': '101',
#     'pubYear': '2022',
#     'journalIssn': '0304-5412; 1536-5964; ',
#     'pageInfo': 'e30952',
#     'pubType': 'systematic review; journal article; case reports',
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-10-13',
#     'firstPublicationDate': '2022-10-01'},
#    {'id': '36162491',
#     'source': 'MED',
#     'pmid': '36162491',
#     'doi': '10.1016/j.ad.2022.09.011',
#     'title': 'Cutaneous Manifestations not Considered Diagnostic Criteria for Neurofibromatosis Type 1. A Case-Control Study.',
#     'authorString': 'García-Martínez FJ, Duat-Rodríguez, Andrés Esteban E, Torrelo, Noguera Morel L, Hernández-Martín.',
#     'journalTitle': 'Actas Dermosifiliogr',
#     'pubYear': '2022',
#     'journalIssn': '0001-7310; 1578-2190; ',
#     'pageInfo': 'S0001-7310(22)00800-6',
#     'pubType': 'journal article',
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-28',
#     'firstPublicationDate': '2022-09-23'},
#    {'id': '36139671',
#     'source': 'MED',
#     'pmid': '36139671',
#     'pmcid': 'PMC9497298',
#     'fullTextIdList': {'fullTextId': ['PMC9497298']},
#     'doi': '10.3390/cancers14184513',
#     'title': 'Neurofibroma Development in Neurofibromatosis Type 1: Insights from Cellular Origin and Schwann Cell Lineage Development.',
#     'authorString': 'Ge LL, Xing MY, Zhang HB, Wang ZC.',
#     'journalTitle': 'Cancers (Basel)',
#     'issue': '18',
#     'journalVolume': '14',
#     'pubYear': '2022',
#     'journalIssn': '2072-6694',
#     'pageInfo': '4513',
#     'pubType': 'review-article; review; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-26',
#     'firstPublicationDate': '2022-09-17'},
#    {'id': '36028856',
#     'source': 'MED',
#     'pmid': '36028856',
#     'pmcid': 'PMC9419337',
#     'fullTextIdList': {'fullTextId': ['PMC9419337']},
#     'doi': '10.1186/s13023-022-02493-5',
#     'title': 'Development of algorithms to identify individuals with Neurofibromatosis type 1 within administrative data and electronic medical records in Ontario, Canada.',
#     'authorString': 'Barnett C, Candido E, Chen B, Pequeno P, Parkin PC, Tu K.',
#     'journalTitle': 'Orphanet J Rare Dis',
#     'issue': '1',
#     'journalVolume': '17',
#     'pubYear': '2022',
#     'journalIssn': '1750-1172',
#     'pageInfo': '321',
#     'pubType': "research support, non-u.s. gov't; research-article; research support, u.s. gov't, non-p.h.s.; journal article",
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-08-28',
#     'firstPublicationDate': '2022-08-26'},
#    {'id': '36117804',
#     'source': 'MED',
#     'pmid': '36117804',
#     'pmcid': 'PMC9478197',
#     'fullTextIdList': {'fullTextId': ['PMC9478197']},
#     'doi': '10.3389/fsurg.2022.908573',
#     'title': 'Current update on the visual outcome of optic pathway glioma associated with neurofibromatosis type-1.',
#     'authorString': 'Zeid JL.',
#     'journalTitle': 'Front Surg',
#     'journalVolume': '9',
#     'pubYear': '2022',
#     'journalIssn': '2296-875x',
#     'pageInfo': '908573',
#     'pubType': 'review-article; review; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-20',
#     'firstPublicationDate': '2022-09-02'},
#    {'id': '36037004',
#     'source': 'MED',
#     'pmid': '36037004',
#     'pmcid': 'PMC9459395',
#     'fullTextIdList': {'fullTextId': ['PMC9459395']},
#     'doi': '10.1242/dmm.049422',
#     'title': 'Mechanistic insights from animal models of neurofibromatosis type 1 cognitive impairment.',
#     'authorString': 'Miller AH, Halloran MC.',
#     'journalTitle': 'Dis Model Mech',
#     'issue': '8',
#     'journalVolume': '15',
#     'pubYear': '2022',
#     'journalIssn': '1754-8403; 1754-8411; ',
#     'pageInfo': 'dmm049422',
#     'pubType': "research support, non-u.s. gov't; review-article; review; journal article; research support, n.i.h., extramural",
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-08-30',
#     'firstPublicationDate': '2022-08-29'},
#    {'id': '36202290',
#     'source': 'MED',
#     'pmid': '36202290',
#     'doi': '10.1016/j.nbd.2022.105881',
#     'title': 'Multimodal assessment of the GABA system in patients with fragile-X syndrome and neurofibromatosis of type 1.',
#     'authorString': 'Lacroix A, Proteau-Lemieux M, Côté S, Near J, Hui SCN, Edden RAE, Lippé S, Çaku A, Corbin F, Lepage JF.',
#     'journalTitle': 'Neurobiol Dis',
#     'journalVolume': '174',
#     'pubYear': '2022',
#     'journalIssn': '0969-9961; 1095-953x; ',
#     'pageInfo': '105881',
#     'pubType': 'journal article',
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-10-07',
#     'firstPublicationDate': '2022-10-03'},
#    {'id': '36134665',
#     'source': 'MED',
#     'pmid': '36134665',
#     'doi': '10.1172/jci.insight.154513',
#     'title': 'Multiple Nf1 Schwann cell populations reprogram the plexiform neurofibroma tumor microenvironment.',
#     'authorString': 'Kershner LJ, Choi K, Wu J, Zhang X, Perrino M, Salomonis N, Shern JF, Ratner N.',
#     'journalTitle': 'JCI Insight',
#     'issue': '18',
#     'journalVolume': '7',
#     'pubYear': '2022',
#     'journalIssn': '2379-3708',
#     'pageInfo': 'e154513',
#     'pubType': "research support, u.s. gov't, non-p.h.s.; journal article; research support, n.i.h., extramural",
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-23',
#     'firstPublicationDate': '2022-09-22'},
#    {'id': '35426432',
#     'source': 'MED',
#     'pmid': '35426432',
#     'pmcid': 'PMC9527508',
#     'fullTextIdList': {'fullTextId': ['PMC9527508']},
#     'doi': '10.1093/neuonc/noac100',
#     'title': 'Evaluation of magnetic resonance imaging-based radiomics characteristics for differentiation of benign and malignant peripheral nerve sheath tumors in neurofibromatosis type 1.',
#     'authorString': 'Ristow I, Madesta F, Well L, Shenas F, Wright F, Molwitz I, Farschtschi S, Bannas P, Adam G, Mautner VF, Werner R, Salamon J.',
#     'journalTitle': 'Neuro Oncol',
#     'issue': '10',
#     'journalVolume': '24',
#     'pubYear': '2022',
#     'journalIssn': '1522-8517; 1523-5866; ',
#     'pageInfo': '1790-1798',
#     'pubType': 'research-article; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-04-16',
#     'firstPublicationDate': '2022-10-01'},
#    {'id': '36061378',
#     'source': 'MED',
#     'pmid': '36061378',
#     'pmcid': 'PMC9434403',
#     'fullTextIdList': {'fullTextId': ['PMC9434403']},
#     'doi': '10.3389/fped.2022.918136',
#     'title': 'Genotypes and clinical intervention of patients with neurofibromatosis type 1 associated dystrophic scoliosis.',
#     'authorString': 'Li H, Zhang W, Yao Z, Guo R, Hao C, Zhang X.',
#     'journalTitle': 'Front Pediatr',
#     'journalVolume': '10',
#     'pubYear': '2022',
#     'journalIssn': '2296-2360',
#     'pageInfo': '918136',
#     'pubType': 'research-article; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'Y',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-05',
#     'firstPublicationDate': '2022-08-18'},
#    {'id': 'PPR535210',
#     'source': 'PPR',
#     'doi': '10.21203/rs.3.rs-1887374/v2',
#     'title': 'Abnormal Peripheral Blood Cell Counts in Neurofibromatosis Type 1',
#     'authorString': 'Nobeyama Y, Yasuda K, Asahina A.',
#     'pubYear': '2022',
#     'pubType': 'preprint',
#     'bookOrReportDetails': {'publisher': 'Research Square',
#      'yearOfPublication': 2022},
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'N',
#     'versionNumber': 2,
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-08-24',
#     'firstPublicationDate': '2022-08-23'},
#    {'id': '36038126',
#     'source': 'MED',
#     'pmid': '36038126',
#     'doi': '10.1016/j.jormas.2022.08.014',
#     'title': 'Evaluation of the Sense of Taste and Smell in Patients with Neurofibromatosis Type 1.',
#     'authorString': 'Speth US, König D, Burg S, Gosau M, Friedrich RE.',
#     'journalTitle': 'J Stomatol Oral Maxillofac Surg',
#     'pubYear': '2022',
#     'journalIssn': '2468-8509; 2468-7855; ',
#     'pageInfo': 'S2468-7855(22)00240-3',
#     'pubType': 'journal article',
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-08-30',
#     'firstPublicationDate': '2022-08-28'},
#    {'id': '36090331',
#     'source': 'MED',
#     'pmid': '36090331',
#     'pmcid': 'PMC9458937',
#     'fullTextIdList': {'fullTextId': ['PMC9458937']},
#     'doi': '10.3389/fsurg.2022.939705',
#     'title': 'Laparoscopic retroperitoneal resection of the duodenal gastrointestinal stromal tumors in neurofibromatosis type 1; Case Report and literature review.',
#     'authorString': 'Abdullah AD, Mohammed S, Alradhi M, Zhu X, Yang D.',
#     'journalTitle': 'Front Surg',
#     'journalVolume': '9',
#     'pubYear': '2022',
#     'journalIssn': '2296-875x',
#     'pageInfo': '939705',
#     'pubType': 'case reports; case-report',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-13',
#     'firstPublicationDate': '2022-08-26'},
#    {'id': '36009591',
#     'source': 'MED',
#     'pmid': '36009591',
#     'pmcid': 'PMC9405573',
#     'fullTextIdList': {'fullTextId': ['PMC9405573']},
#     'doi': '10.3390/biomedicines10082044',
#     'title': 'Identification of Germinal Neurofibromin Hotspots.',
#     'authorString': 'Lois S, Báez-Flores J, Isidoro-García M, Lacal J, Triviño JC.',
#     'journalTitle': 'Biomedicines',
#     'issue': '8',
#     'journalVolume': '10',
#     'pubYear': '2022',
#     'journalIssn': '2227-9059',
#     'pageInfo': '2044',
#     'pubType': 'research-article; journal article',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'Y',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'Y',
#     'tmAccessionTypeList': {'accessionType': ['omim', 'uniprot']},
#     'firstIndexDate': '2022-08-27',
#     'firstPublicationDate': '2022-08-21'},
#    {'id': '35945271',
#     'source': 'MED',
#     'pmid': '35945271',
#     'doi': '10.1038/s10038-022-01072-7',
#     'title': 'Functional restoration of mouse Nf1 nonsense alleles in differentiated cultured neurons.',
#     'authorString': 'Wu C, Iyer S, Wolfe SA, Jacobson A.',
#     'journalTitle': 'J Hum Genet',
#     'pubYear': '2022',
#     'journalIssn': '1434-5161; 1435-232x; ',
#     'pubType': 'journal article',
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-08-10',
#     'firstPublicationDate': '2022-08-09'},
#    {'id': '36096471',
#     'source': 'MED',
#     'pmid': '36096471',
#     'doi': '10.1016/j.ejmg.2022.104609',
#     'title': 'Abdominal tumors in patients with neurofibromatosis type I: Genotype-phenotype relationships.',
#     'authorString': 'Matas-Nadal C, Soria X, Gonzalez-Farré M, Baradad M, Tuset N, Rius Riu F, González M, Gatius S, Vilardell F, López-Ortega R, Martí RM.',
#     'journalTitle': 'Eur J Med Genet',
#     'issue': '11',
#     'journalVolume': '65',
#     'pubYear': '2022',
#     'journalIssn': '1769-7212; 1878-0849; ',
#     'pageInfo': '104609',
#     'pubType': 'journal article',
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-14',
#     'firstPublicationDate': '2022-09-10'},
#    {'id': '35979058',
#     'source': 'MED',
#     'pmid': '35979058',
#     'pmcid': 'PMC9376313',
#     'fullTextIdList': {'fullTextId': ['PMC9376313']},
#     'doi': '10.3389/fneur.2022.874613',
#     'title': 'The gene diagnosis of neurofibromatosis type I with headache as the main symptom: A case report and review of the literature.',
#     'authorString': 'Gao M, Liu H, Sun Q, Yang G.',
#     'journalTitle': 'Front Neurol',
#     'journalVolume': '13',
#     'pubYear': '2022',
#     'journalIssn': '1664-2295',
#     'pageInfo': '874613',
#     'pubType': 'case reports; case-report',
#     'isOpenAccess': 'Y',
#     'inEPMC': 'Y',
#     'inPMC': 'N',
#     'hasPDF': 'Y',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'Y',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-08-19',
#     'firstPublicationDate': '2022-08-01'},
#    {'id': 'PPR540514',
#     'source': 'PPR',
#     'doi': '10.21203/rs.3.rs-2012218/v1',
#     'title': 'Assessment of rare genetic variants to identify candidate modifier genes underlying neurological manifestations in neurofibromatosis 1 patients',
#     'authorString': 'Tang J, Li N, Li Gq, Wang J, Yu T, Yao Re.',
#     'pubYear': '2022',
#     'pubType': 'preprint',
#     'bookOrReportDetails': {'publisher': 'Research Square',
#      'yearOfPublication': 2022},
#     'isOpenAccess': 'N',
#     'inEPMC': 'N',
#     'inPMC': 'N',
#     'hasPDF': 'N',
#     'hasBook': 'N',
#     'hasSuppl': 'N',
#     'citedByCount': 0,
#     'hasReferences': 'N',
#     'hasTextMinedTerms': 'Y',
#     'hasDbCrossReferences': 'N',
#     'hasLabsLinks': 'Y',
#     'hasTMAccessionNumbers': 'N',
#     'firstIndexDate': '2022-09-07',
#     'firstPublicationDate': '2022-09-06'}]}}

# %%
content
# Out:
# b''
